# %% [markdown]
# ### Ok this is my fourth attempt.
# ###### This time I will split each match into two rows, one for the winner, one for the loser.
# ###### Different POVs, and an indicator of the victor

# %%
import pandas as pd
import numpy as np
import matplotlib
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

pd.set_option('display.max_columns', None) ### This line makes all the columns display, rather than ellipses shorten

atp_2022_frame = pd.read_csv('C:/Users/aaron/Code/Data/atp_matches_2022.csv', parse_dates=[5])

atp_2023_frame = pd.read_csv('C:/Users/aaron/Code/Data/atp_matches_2023.csv', parse_dates=[5])

# %%
atp_2022_frame.iloc[55:58]
# Out:
#    tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 55  2022-8998   Adelaide 1    Hard         32             A   2022-01-03
# 56  2022-8998   Adelaide 1    Hard         32             A   2022-01-03
# 57  2022-8998   Adelaide 1    Hard         32             A   2022-01-03
#
#     match_num  winner_id  winner_seed winner_entry      winner_name  \
# 55        299     104792          1.0          NaN     Gael Monfils
# 56        298     111575          2.0          NaN  Karen Khachanov
# 57        297     104792          1.0          NaN     Gael Monfils
#
#    winner_hand  winner_ht winner_ioc  winner_age  loser_id  loser_seed  \
# 55           R      193.0        FRA        35.3    106423         NaN
# 56           R      198.0        RUS        25.6    105227         3.0
# 57           R      193.0        FRA        35.3    126205         6.0
#
#    loser_entry          loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 55          WC  Thanasi Kokkinakis          R     196.0       AUS       25.7
# 56         NaN         Marin Cilic          R     198.0       CRO       33.2
# 57         NaN          Tommy Paul          R     185.0       USA       24.6
#
#          score  best_of round  minutes  w_ace  w_df  w_svpt  w_1stIn  \
# 55     7-5 6-0        3    SF     80.0    7.0   3.0    57.0     33.0
# 56  7-6(3) 6-3        3    SF    114.0    6.0   2.0    87.0     62.0
# 57     6-4 6-1        3    QF     68.0    5.0   4.0    52.0     31.0
#
#     w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  l_svpt  \
# 55      28.0      12.0      9.0        4.0        4.0    4.0   2.0    58.0
# 56      46.0      13.0     11.0        4.0        4.0    8.0   3.0    67.0
# 57      23.0      11.0      9.0        2.0        4.0    1.0   1.0    47.0
#
#     l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# 55     41.0      23.0       8.0      9.0        6.0       10.0         21.0
# 56     36.0      28.0      15.0     10.0        1.0        2.0         29.0
# 57     27.0      18.0       5.0      8.0        2.0        7.0         21.0
#
#     winner_rank_points  loser_rank  loser_rank_points
# 55              2158.0       171.0              394.0
# 56              1731.0        30.0             1710.0
# 57              2158.0        43.0             1349.0

# %%
atp_2022_frame['surface_cat'] = atp_2022_frame['surface'].astype("category").cat.codes ## Add a surface category column
atp_2023_frame['surface_cat'] = atp_2023_frame['surface'].astype("category").cat.codes ## Add a surface category column

# %%
atp_2022_frame.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points',
#        'surface_cat'],
#       dtype='object')

# %%
### make df for just winners
#columns_to_keep_for_winners = ['tourney_name','surface','match_num','winner_id','winner_name','winner_hand','winner_ht','winner_age', 'minutes',
 #                              'w_ace', 'w_df','w_svpt','w_1stIn','w_1stWon','w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'winner_rank']




winning_rename_lib = {'winner_id':'player_id', 'winner_seed':'player_seed', 'winner_entry':'player_entry',
       'winner_name':'player_name', 'winner_hand':'player_hand', 'winner_ht':'player_ht', 'winner_ioc':'player_ioc', 'winner_age':'player_age',
       'loser_id':'opponent_id', 'loser_seed':'opponent_seed', 'loser_entry':'opponent_entry', 'loser_name':'opponent_name', 'loser_hand':'opponent_hand',
       'loser_ht': 'opponent_ht', 'loser_ioc':'opponent_ioc', 'loser_age':'opponent_age',
        'w_ace':'player_ace', 'w_df':'player_df', 'w_svpt':'player_svpt', 'w_1stIn':'player_1stIn', 'w_1stWon':'player_1stWon', 'w_2ndWon':'player_2ndWon',
       'w_SvGms':'player_SvGms', 'w_bpSaved':'player_bpSaved', 'w_bpFaced':'player_bpFaced', 'l_ace':'opponent_ace', 'l_df':'opponent_df', 'l_svpt':'opponent_svpt',
       'l_1stIn':'opponent_1stIn', 'l_1stWon':'opponent_1stWon', 'l_2ndWon':'opponent_2ndWon', 'l_SvGms':'opponent_SvGms', 'l_bpSaved':'opponent_bpSaved', 'l_bpFaced':'opponent_bpFaced',
       'winner_rank':'player_rank', 'winner_rank_points':'player_rank_points', 'loser_rank':'opponent_rank', 'loser_rank_points':'opponent_rank_points'}

losing_rename_lib = {'winner_id':'opponent_id', 'winner_seed':'opponent_seed', 'winner_entry':'opponent_entry',
       'winner_name':'opponent_name', 'winner_hand':'opponent_hand', 'winner_ht':'opponent_ht', 'winner_ioc':'opponent_ioc', 'winner_age':'opponent_age',
       'loser_id':'player_id', 'loser_seed':'player_seed', 'loser_entry':'player_entry', 'loser_name':'player_name', 'loser_hand':'player_hand',
       'loser_ht': 'player_ht', 'loser_ioc':'player_ioc', 'loser_age':'player_age',
        'w_ace':'opponent_ace', 'w_df':'opponent_df', 'w_svpt':'opponent_svpt', 'w_1stIn':'opponent_1stIn', 'w_1stWon':'opponent_1stWon', 'w_2ndWon':'opponent_2ndWon',
       'w_SvGms':'opponent_SvGms', 'w_bpSaved':'opponent_bpSaved', 'w_bpFaced':'opponent_bpFaced', 'l_ace':'player_ace', 'l_df':'player_df', 'l_svpt':'player_svpt',
       'l_1stIn':'player_1stIn', 'l_1stWon':'player_1stWon', 'l_2ndWon':'player_2ndWon', 'l_SvGms':'player_SvGms', 'l_bpSaved':'player_bpSaved', 'l_bpFaced':'player_bpFaced',
       'winner_rank':'opponent_rank', 'winner_rank_points':'opponent_rank_points', 'loser_rank':'player_rank', 'loser_rank_points':'player_rank_points'}

#losing_rename_lib = {'loser_rank':'player_rank', 'winner_rank':'opponent_rank', 'loser_age':'player_age', 'winner_age':'opponent_age', 'loser_ht':'player_height', 'winner_ht':'opponent_height', 'loser_hand':'player_hand', 'winner_hand':'opponent_hand'} #rename columns
    
winners_of_2022_df = atp_2022_frame.rename(columns = winning_rename_lib)
losers_of_2022_df = atp_2022_frame.rename(columns = losing_rename_lib)
winners_of_2023_df = atp_2023_frame.rename(columns = winning_rename_lib)
losers_of_2023_df = atp_2023_frame.rename(columns = losing_rename_lib)

#winners_of_2022_df = atp_2022_frame[columns_to_keep_for_winners]

losers_of_2022_df['result'] = 'L'
winners_of_2022_df['result'] = 'W'
losers_of_2023_df['result'] = 'L'
winners_of_2023_df['result'] = 'W'

each_match_twice_2022 = pd.concat([winners_of_2022_df, losers_of_2022_df], axis = 0)
each_match_twice_2023 = pd.concat([winners_of_2023_df, losers_of_2023_df], axis = 0)

#each_match_twice_2022 = winners_of_2022_df.append(losers_of_2022_df)#pd.concat([winners_of_2022_df, losers_of_2022_df])

# %%
 ### trying to make sure each player's matches are in consecutive order (i think im satisfied with the result)
each_match_twice_2022 = each_match_twice_2022.sort_values(by = ['tourney_date', 'tourney_id','match_num'])
each_match_twice_2023 = each_match_twice_2023.sort_values(by = ['tourney_date', 'tourney_id','match_num'])

# %%
#### make some columns for things like break point coverted percent, ace to df percent, bp saved percent .... etcetera

# %%
each_match_twice_2022.iloc[350:359]
# Out:
#     tourney_id     tourney_name surface  draw_size tourney_level tourney_date  \
# 175   2022-580  Australian Open    Hard        128             G   2022-01-17
# 175   2022-580  Australian Open    Hard        128             G   2022-01-17
# 176   2022-580  Australian Open    Hard        128             G   2022-01-17
# 176   2022-580  Australian Open    Hard        128             G   2022-01-17
# 177   2022-580  Australian Open    Hard        128             G   2022-01-17
# 177   2022-580  Australian Open    Hard        128             G   2022-01-17
# 178   2022-580  Australian Open    Hard        128             G   2022-01-17
# 178   2022-580  Australian Open    Hard        128             G   2022-01-17
# 179   2022-580  Australian Open    Hard        128             G   2022-01-17
#
#      match_num  player_id  player_seed player_entry        player_name  \
# 175        113     105583          NaN          NaN      Dusan Lajovic
# 175        113     105916          NaN          NaN   Marton Fucsovics
# 176        114     111578          NaN           WC      Stefan Kozlov
# 176        114     106210          NaN          NaN        Jiri Vesely
# 177        115     126610          7.0          NaN  Matteo Berrettini
# 177        115     206909          NaN          NaN  Brandon Nakashima
# 178        116     100644          3.0          NaN   Alexander Zverev
# 178        116     127157          NaN          NaN    Daniel Altmaier
# 179        117     105357          NaN          NaN       John Millman
#
#     player_hand  player_ht player_ioc  player_age  opponent_id  opponent_seed  \
# 175           R      180.0        SRB        31.5       105916            NaN
# 175           R      188.0        HUN        29.9       105583            NaN
# 176           R      183.0        USA        23.9       106210            NaN
# 176           L      198.0        CZE        28.5       111578            NaN
# 177           R      196.0        ITA        25.7       206909            NaN
# 177           R      185.0        USA        20.4       126610            7.0
# 178           R      198.0        GER        24.7       127157            NaN
# 178           R      191.0        GER        23.3       100644            3.0
# 179           R      183.0        AUS        32.5       103852            NaN
#
#     opponent_entry      opponent_name opponent_hand  opponent_ht opponent_ioc  \
# 175            NaN   Marton Fucsovics             R        188.0          HUN
# 175            NaN      Dusan Lajovic             R        180.0          SRB
# 176            NaN        Jiri Vesely             L        198.0          CZE
# 176             WC      Stefan Kozlov             R        183.0          USA
# 177            NaN  Brandon Nakashima             R        185.0          USA
# 177            NaN  Matteo Berrettini             R        196.0          ITA
# 178            NaN    Daniel Altmaier             R        191.0          GER
# 178            NaN   Alexander Zverev             R        198.0          GER
# 179            NaN    Feliciano Lopez             L        188.0          ESP
#
#      opponent_age                   score  best_of round  minutes  player_ace  \
# 175          29.9  6-3 4-6 6-1 6-7(6) 6-1        5  R128    203.0         9.0
# 175          31.5  6-3 4-6 6-1 6-7(6) 6-1        5  R128    203.0        10.0
# 176          28.5             7-5 6-3 6-4        5  R128    155.0         5.0
# 176          23.9             7-5 6-3 6-4        5  R128    155.0         3.0
# 177          20.4      4-6 6-2 7-6(5) 6-3        5  R128    190.0        21.0
# 177          25.7      4-6 6-2 7-6(5) 6-3        5  R128    190.0        12.0
# 178          23.3       7-6(3) 6-1 7-6(1)        5  R128    158.0        14.0
# 178          24.7       7-6(3) 6-1 7-6(1)        5  R128    158.0         1.0
# 179          40.3         6-1 6-3 4-6 7-5        5  R128    172.0         6.0
#
#      player_df  player_svpt  player_1stIn  player_1stWon  player_2ndWon  \
# 175        2.0        133.0         100.0           78.0           15.0
# 175        8.0        155.0          98.0           62.0           29.0
# 176        7.0         96.0          66.0           52.0           18.0
# 176        4.0         98.0          58.0           45.0           18.0
# 177        2.0        129.0          78.0           57.0           30.0
# 177        2.0        117.0          77.0           57.0           19.0
# 178        6.0         91.0          65.0           57.0           10.0
# 178        3.0        127.0          73.0           48.0           22.0
# 179        0.0        121.0          77.0           55.0           25.0
#
#      player_SvGms  player_bpSaved  player_bpFaced  opponent_ace  opponent_df  \
# 175          23.0             2.0             4.0          10.0          8.0
# 175          22.0             7.0            14.0           9.0          2.0
# 176          16.0             4.0             4.0           3.0          4.0
# 176          15.0             5.0             8.0           5.0          7.0
# 177          20.0             8.0             9.0          12.0          2.0
# 177          19.0             8.0            11.0          21.0          2.0
# 178          16.0             0.0             1.0           1.0          3.0
# 178          15.0            14.0            18.0          14.0          6.0
# 179          19.0             5.0             7.0          26.0          5.0
#
#      opponent_svpt  opponent_1stIn  opponent_1stWon  opponent_2ndWon  \
# 175          155.0            98.0             62.0             29.0
# 175          133.0           100.0             78.0             15.0
# 176           98.0            58.0             45.0             18.0
# 176           96.0            66.0             52.0             18.0
# 177          117.0            77.0             57.0             19.0
# 177          129.0            78.0             57.0             30.0
# 178          127.0            73.0             48.0             22.0
# 178           91.0            65.0             57.0             10.0
# 179          132.0            78.0             57.0             18.0
#
#      opponent_SvGms  opponent_bpSaved  opponent_bpFaced  player_rank  \
# 175            22.0               7.0              14.0         39.0
# 175            23.0               2.0               4.0         35.0
# 176            15.0               5.0               8.0        169.0
# 176            16.0               4.0               4.0         78.0
# 177            19.0               8.0              11.0          7.0
# 177            20.0               8.0               9.0         68.0
# 178            15.0              14.0              18.0          3.0
# 178            16.0               0.0               1.0         87.0
# 179            19.0              15.0              21.0         89.0
#
#      player_rank_points  opponent_rank  opponent_rank_points  surface_cat  \
# 175              1346.0           35.0                1457.0            2
# 175              1457.0           39.0                1346.0            2
# 176               401.0           78.0                 824.0            2
# 176               824.0          169.0                 401.0            2
# 177              4568.0           68.0                 917.0            2
# 177               917.0            7.0                4568.0            2
# 178              7970.0           87.0                 792.0            2
# 178               792.0            3.0                7970.0            2
# 179               788.0          109.0                 696.0            2
#
#     result
# 175      W
# 175      L
# 176      W
# 176      L
# 177      W
# 177      L
# 178      W
# 178      L
# 179      W

# %%
grouped_matches_2022 = each_match_twice_2022.groupby('player_name')
grouped_matches_2023 = each_match_twice_2022.groupby('player_name')

# %%
single_player = grouped_matches_2022.get_group('John Millman')

#single_player

# %%
def rolling_averages(group, columns, new_columns):
    rolling_stats = group[columns].rolling(3, closed='left').mean()
    group[new_columns] = rolling_stats
    group = group.dropna(subset=new_columns)
    return group

# %%
columns = ['player_df', 'player_1stIn','player_1stWon', 'player_2ndWon']
new_columns = [f"{c}_rolling" for c in columns]

# %%
rolling_averages(single_player, columns, new_columns)
# Out:
# C:\Users\aaron\AppData\Local\Temp\ipykernel_7612\74715329.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group[new_columns] = rolling_stats
# C:\Users\aaron\AppData\Local\Temp\ipykernel_7612\74715329.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group[new_columns] = rolling_stats
# C:\Users\aaron\AppData\Local\Temp\ipykernel_7612\74715329.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group[new_columns] = rolling_stats
# C:\Users\aaron\AppData\Local\Temp\ipykernel_7612\74715329.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group[new_columns] = rolling_stats
#      tourney_id          tourney_name surface  draw_size tourney_level  \
# 234    2022-580       Australian Open    Hard        128             G
# 448   2022-0424                Dallas    Hard         32             A
# 476   2022-0499          Delray Beach    Hard         32             A
# 466   2022-0499          Delray Beach    Hard         32             A
# 460   2022-0499          Delray Beach    Hard         32             A
# 457   2022-0499          Delray Beach    Hard         32             A
# 587   2022-0807              Acapulco    Hard         32             A
# 737   2022-0404  Indian Wells Masters    Hard        128             M
# 705   2022-0404  Indian Wells Masters    Hard        128             M
# 835   2022-0403         Miami Masters    Hard        128             M
# 1018  2022-5053             Belgrade     Clay         32             A
# 1010  2022-5053             Belgrade     Clay         32             A
# 1081  2022-0308                Munich    Clay         32             A
# 1208  2022-0322                Geneva    Clay         32             A
# 1275   2022-520         Roland Garros    Clay        128             G
# 1538  2022-0741            Eastbourne   Grass         32             A
# 1527  2022-0741            Eastbourne   Grass         32             A
# 1547   2022-540             Wimbledon   Grass        128             G
# 1805  2022-6116               Atlanta    Hard         32             A
# 1794  2022-6116               Atlanta    Hard         32             A
# 2087  2022-6242         Winston-Salem    Hard         64             A
# 2071  2022-6242         Winston-Salem    Hard         64             A
# 2116   2022-560               Us Open    Hard        128             G
#
#      tourney_date  match_num  player_id  player_seed player_entry  \
# 234    2022-01-17        172     105357          NaN          NaN
# 448    2022-02-07        278     105357          NaN          NaN
# 476    2022-02-14        277     105357          NaN          NaN
# 466    2022-02-14        289     105357          NaN          NaN
# 460    2022-02-14        295     105357          NaN          NaN
# 457    2022-02-14        298     105357          NaN          NaN
# 587    2022-02-21        276     105357          NaN           SE
# 737    2022-03-07        192     105357          NaN           LL
# 705    2022-03-07        247     105357          NaN           LL
# 835    2022-03-21        187     105357          NaN          NaN
# 1018   2022-04-18        283     105357          NaN          NaN
# 1010   2022-04-18        292     105357          NaN          NaN
# 1081   2022-04-25        272     105357          NaN          NaN
# 1208   2022-05-16        284     105357          NaN          NaN
# 1275   2022-05-23        128     105357          NaN          NaN
# 1538   2022-06-20        277     105357          NaN            Q
# 1527   2022-06-20        290     105357          NaN            Q
# 1547   2022-06-27        103     105357          NaN          NaN
# 1805   2022-07-25        276     105357          NaN          NaN
# 1794   2022-07-25        289     105357          NaN          NaN
# 2087   2022-08-22        252     105357          NaN          NaN
# 2071   2022-08-22        277     105357          NaN          NaN
# 2116   2022-08-29        121     105357          NaN          NaN
#
#        player_name player_hand  player_ht player_ioc  player_age  opponent_id  \
# 234   John Millman           R      183.0        AUS        32.5       100644
# 448   John Millman           R      183.0        AUS        32.6       206909
# 476   John Millman           R      183.0        AUS        32.6       202195
# 466   John Millman           R      183.0        AUS        32.6       106218
# 460   John Millman           R      183.0        AUS        32.6       105777
# 457   John Millman           R      183.0        AUS        32.6       124187
# 587   John Millman           R      183.0        AUS        32.6       106218
# 737   John Millman           R      183.0        AUS        32.7       105526
# 705   John Millman           R      183.0        AUS        32.7       200282
# 835   John Millman           R      183.0        AUS        32.7       123755
# 1018  John Millman           R      183.0        AUS        32.8       106233
# 1010  John Millman           R      183.0        AUS        32.8       200175
# 1081  John Millman           R      183.0        AUS        32.8       106078
# 1208  John Millman           R      183.0        AUS        32.9       104755
# 1275  John Millman           R      183.0        AUS        32.9       200624
# 1538  John Millman           R      183.0        AUS        33.0       200624
# 1527  John Millman           R      183.0        AUS        33.0       122330
# 1547  John Millman           R      183.0        AUS        33.0       200175
# 1805  John Millman           R      183.0        AUS        33.1       200615
# 1794  John Millman           R      183.0        AUS        33.1       206909
# 2087  John Millman           R      183.0        AUS        33.1       200384
# 2071  John Millman           R      183.0        AUS        33.1       105077
# 2116  John Millman           R      183.0        AUS        33.2       207182
#
#       opponent_seed opponent_entry       opponent_name opponent_hand  \
# 234             3.0            NaN    Alexander Zverev             R
# 448             8.0            NaN   Brandon Nakashima             R
# 476             8.0            NaN       Maxime Cressy             R
# 466             NaN            NaN        Marcos Giron             R
# 460             3.0            NaN     Grigor Dimitrov             R
# 457             2.0            NaN       Reilly Opelka             R
# 587             NaN            NaN        Marcos Giron             R
# 737             NaN            NaN  Jan Lennard Struff             R
# 705            29.0            NaN      Alex De Minaur             R
# 835             NaN              Q  Daniel Elahi Galan             R
# 1018            NaN            NaN       Dominic Thiem             R
# 1010            7.0            NaN   Miomir Kecmanovic             R
# 1081            NaN              Q      Egor Gerasimov             R
# 1208            NaN            NaN     Richard Gasquet             R
# 1275           27.0            NaN     Sebastian Korda             R
# 1538            NaN            NaN     Sebastian Korda             R
# 1527            NaN            NaN    Alexander Bublik             R
# 1547           25.0            NaN   Miomir Kecmanovic             R
# 1805            NaN            NaN      Alexei Popyrin             R
# 1794            8.0            NaN   Brandon Nakashima             R
# 2087            NaN            NaN         Hugo Gaston             L
# 2071            8.0            NaN        Albert Ramos             L
# 2116            NaN            NaN         Emilio Nava             R
#
#       opponent_ht opponent_ioc  opponent_age                      score  \
# 234         198.0          GER          24.7                6-4 6-4 6-0
# 448         185.0          USA          20.5                 7-5 7-6(3)
# 476         198.0          USA          24.7       6-7(2) 7-6(2) 7-6(3)
# 466         180.0          USA          28.5                 6-3 7-6(6)
# 460         188.0          BUL          30.7                    6-4 6-4
# 457         211.0          USA          24.4       7-6(8) 6-7(3) 7-6(4)
# 587         180.0          USA          28.5             7-6(3) 2-0 RET
# 737         193.0          GER          31.8                 7-6(6) 6-4
# 705         183.0          AUS          23.0                 7-6(4) 6-3
# 835         191.0          COL          25.7                    6-4 6-2
# 1018        185.0          AUT          28.6                6-3 3-6 6-4
# 1010        183.0          SRB          22.6                 6-4 7-6(5)
# 457                738.0           20.0                2051.0            2
# 587                818.0           59.0                 990.0            2
# 737                818.0           58.0                 984.0            2
# 705                818.0           31.0                1451.0            2
# 835                838.0          118.0                 554.0            2
# 1018               793.0           54.0                 975.0            0
# 1010               793.0           38.0                1211.0            0
# 1081               793.0          150.0                 412.0            0
# 1208               698.0           75.0                 808.0            0
# 1275               693.0           30.0                1326.0            0
# 1538               664.0           46.0                1028.0            1
# 1527               664.0           39.0                1105.0            1
# 1547               676.0           30.0                1306.0            1
# 1805               631.0           84.0                 624.0            2
# 1794               631.0           56.0                 824.0            2
# 2087               516.0           71.0                 692.0            2
# 2071               516.0           42.0                1050.0            2
# 2116               526.0          203.0                 258.0            2
#
#      result  player_df_rolling  player_1stIn_rolling  player_1stWon_rolling  \
# 234       L           1.000000             50.666667              34.333333
# 448       L           1.000000             51.000000              32.000000
# 476       W           0.333333             53.333333              33.666667
# 466       W           2.000000             51.666667              34.333333
# 460       W           2.333333             54.000000              41.000000
# 457       L           2.333333             52.000000              40.666667
# 587       L           1.333333             59.000000              43.333333
# 737       W           1.000000             55.666667              38.000000
# 705       L           1.333333             59.333333              41.333333
# 835       L           0.666667             40.000000              26.666667
# 1018      W           0.666667             39.333333              25.333333
# 1010      L           0.333333             41.333333              23.666667
# 1081      L           0.333333             50.000000              28.000000
# 1208      L           1.000000             59.666667              34.000000
# 1275      L           1.333333             52.333333              30.000000
# 1538      W           1.666667             60.333333              35.666667
# 1527      L           1.333333             52.666667              33.333333
# 1547      L           1.333333             49.333333              32.000000
# 1805      W           1.666667             44.666667              30.666667
# 1794      L           2.000000             51.333333              37.000000
# 2087      W           2.000000             62.666667              44.333333
# 2071      L           1.333333             51.666667              35.666667
# 2116      L           1.333333             42.666667              26.333333
#
#       player_2ndWon_rolling
# 234               13.666667
# 448               17.333333
# 476               21.000000
# 466               23.333333
# 460               20.000000
# 457               19.000000
# 587               18.000000
# 737               17.333333
# 705               17.000000
# 835               12.000000
# 1018              12.333333
# 1010              17.000000
# 1081              19.666667
# 1208              20.333333
# 1275              14.333333
# 1538               9.666667
# 1527              10.666667
# 1547              11.000000
# 1805              16.000000
# 1794              17.333333
# 2087              18.000000
# 2071              16.000000
# 2116              16.000000

# %%
matches_rolling_2022 = each_match_twice_2022.groupby("player_name").apply(lambda x: rolling_averages(x, columns, new_columns))
matches_rolling_2023 = each_match_twice_2023.groupby("player_name").apply(lambda x: rolling_averages(x, columns, new_columns))

# %%
## This is kinda like reset_index(), it gets rid of the left column
matches_rolling_2022 = matches_rolling_2022.droplevel('player_name')
matches_rolling_2023 = matches_rolling_2023.droplevel('player_name')

# %%
### adding an index by shape
matches_rolling_2022.index = range(matches_rolling_2022.shape[0])
matches_rolling_2023.index = range(matches_rolling_2023.shape[0])

# %%
random_forest = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1, verbose = 1)

# %%
predictors = ["player_rank", "opponent_rank", "player_age", "opponent_age",
              "player_height", "opponent_height", "surface_cat", "player_hand", "opponent_hand", 
              "player_df_rolling", "player_1stIn_rolling", "player_1stWon_rolling", "player_2ndWon_rolling"]

# %%
random_forest.fit(playerFrame2022[predictors], playerFrame2022['result'])

# %%
import requests
from bs4 import BeautifulSoup as bs
from geopy.geocoders import Nominatim

# URL = "https://example.com"
URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)

# print(page.text)

soup = bs(page.content, "html.parser")
#print(soup)

results = soup.find(id="ResultsContainer")
#print(results.prettify)

# %%
import requests
from bs4 import BeautifulSoup as bs


# URL = "https://web.seattle.gov/sfd/realtime911/getRecsForDatePub.asp?action=Today&incDate=&rad1=des"
URL = "https://raw.githubusercontent.com/halmueller/SoupTalk/develop/html_samples/sfdMarch31.html"
page = requests.get(URL)

# print(page.text)

soup = bs(page.content, "html.parser")
#print(soup.prettify)

tables = soup.find_all("table")
print(len(tables))
#print(tables[3])

#for tag in soup.find_all("table"):
#    print("------------------------------------------------------------------------------------------------")
#    print(len(tuple(tag.children)))
#    print(tag.prettify)
#    for c in tag.children:
#        print(c)

# t1 = soup.find("table")
# t2 = soup.find("table")
# t3 = soup.find("table")
# t4 = soup.find("table")
# t5 = soup.find("table")
# t6 = soup.find("table")
# t7 = soup.find("table")
# t8 = soup.find("table")
# t9 = soup.find("table")
# print(t9.prettify)
# Out:
# 4

# %%
import requests
from bs4 import BeautifulSoup as bs


# URL = "https://web.seattle.gov/sfd/realtime911/getRecsForDatePub.asp?action=Today&incDate=&rad1=des"
URL1 = "https://raw.githubusercontent.com/halmueller/SoupTalk/develop/html_samples/sfdApril01.html"
URL2 = "https://raw.githubusercontent.com/halmueller/SoupTalk/develop/html_samples/sfdMarch31.html"
page = requests.get(URL1)

#print(page.text)

soup = bs(page.content, "html.parser")
#print(soup.prettify)

# %%
import requests
from bs4 import BeautifulSoup as bs
import json

URL1 = "https://raw.githubusercontent.com/halmueller/SoupTalk/develop/html_samples/sfdApril01.html"
URL2 = "https://raw.githubusercontent.com/halmueller/SoupTalk/develop/html_samples/sfdMarch31.html"
URL3 = "https://web.seattle.gov/sfd/realtime911/getRecsForDatePub.asp?action=Today&incDate=05%2F01%2F2024&rad1=des"

#page = requests.get(URL1)

page = requests.get(URL3, verify=False)

#print(page.text)

soup = bs(page.content, "html.parser")
#print(soup.prettify)

tables = soup.find_all("table")
#print(len(tables))
#print(tables[3])

# a more Pythonic approach would be a list comprehension
incidents = []
for callRow in tables[3].find_all("tr"):
    fields = callRow.find_all("td")
#    print(fields[4].text)
    row_result = {
        "date" : fields[0].text,
        "incident" : fields[1].text,
        # ignore Level, don't know what it means
        "units" : fields[3].text,
        "address" : fields[4].text,
        "types" : fields[5].text,
        }
    if callRow.find_all("td", {"class": "closed"}):
        row_result["status"] = "closed"
    else:
        row_result["status"] = "open"
    #print(row_result)
    incidents.append(row_result)

#print(incidents)

json_out = json.dumps(incidents)
print(json_out)
# Out:
# C:\Users\aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'web.seattle.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# [{"date": "5/7/2024 7:15:22 PM", "incident": "F240061259", "units": "E39", "address": "12702 15th Ave Ne", "types": "Automatic Medical Alarm", "status": "open"}, {"date": "5/7/2024 7:04:36 PM", "incident": "F240061256", "units": "E24", "address": "600 N 130th St", "types": "Aid Response", "status": "closed"}, {"date": "5/7/2024 7:02:10 PM", "incident": "F240061255", "units": "E6 M10", "address": "RAINIER AVE S / S BAYVIEW ST", "types": "Aid Response", "status": "open"}, {"date": "5/7/2024 7:02:10 PM", "incident": "F240061255", "units": "E30", "address": "RAINIER AVE S / S BAYVIEW ST", "types": "Aid Response", "status": "open"}, {"date": "5/7/2024 7:01:12 PM", "incident": "F240061253", "units": "A10", "address": "204 3rd Ave S", "types": "Aid Response", "status": "open"}, {"date": "5/7/2024 7:00:37 PM", "incident": "F240061252", "units": "A4", "address": "2nd Ave / Union St", "types": "Aid Response", "status": "closed"}, {"date": "5/7/2024 6:58:38 PM", "incident": "F240061250", "units": "E40", "address": "3540 Ne 110th St", "types": "Aid Response", "status": "closed"}, {"date": "5/7/2024 6:49:05 PM", "incident": "F240061247", "units": "E11 M32", "address": "1508 Sw Webster St", "types": "Medic Response", "status": "closed"}, {"date": "5/7/2024 6:43:22 PM", "incident": "F240061245", "units": "E22 E34 M17", "address": "2300 Arboretum Dr E", "types": "Medic Response, 6 per Rule", "status": "open"}, {"date": "5/7/2024 6:38:50 PM", "incident": "F240061243", "units": "E25", "address": "1421 Minor Ave", "types": "Aid Response", "status": "closed"}, {"date": "5/7/2024 6:34:53 PM", "incident": "F240061238", "units": "E18", "address": "4500 15th Ave Nw", "types": "Water Rescue Standby", "status": "closed"}, {"date": "5/7/2024 6:34:53 PM", "incident": "F240061238", "units": "L8", "address": "4500 15th Ave Nw", "types": "Water Rescue Standby", "status": "closed"}, {"date": "5/7/2024 6:38:58 PM", "incident": "F240061242", "units": "E10 L1", "address": "223 Yesler Way", "types": "Auto Fire Alarm", "status": "closed"}, {"date": "5/7/2024 6:36:44 PM", "incident": "F240061239", "units": "E30", "address": "2345 Rainier Ave S", "types": "Aid Response", "status": "closed"}, {"date": "5/7/2024 6:37:16 PM", "incident": "F240061240", "units": "A25", "address": "1014 Boylston Ave", "types": "Aid Response", "status": "closed"}, {"date": "5/7/2024 6:34:53 PM", "incident": "F240061238", "units": "FB4", "address": "4500 15th Ave Nw", "types": "Water Rescue Standby", "status": "closed"}, {"date": "5/7/2024 6:34:53 PM", "incident": "F240061238", "units": "A14 A2 B4 E17 E20 E5 FIREBOAT M18 PTRL4 R1 RB5", "address": "4500 15th Ave Nw", "types": "Water Rescue Standby", "status": "closed"}, {"date": "5/7/2024 6:34:47 PM", "incident": "F240061237", "units": "E18", "address": "4910 15th Ave Nw", "types": "Rubbish Fire", "status": "closed"}, {"date": "5/7/2024 6:32:06 PM", "incident": "F240061233", "units": "M31", "address": "N 105th St / Aurora Ave N", "types": "Medic Response, Overdose", "status": "closed"}, {"date": "5/7/2024 6:32:22 PM", "incident": "F240061235", "units": "E2 L4", "address": "2119 3rd Ave", "types": "Alarm Bell", "status": "closed"}, {"date": "5/7/2024 6:32:06 PM", "incident": "F240061233", "units": "E31 L5 M17", "address": "N 105th St / Aurora Ave N", "types": "Medic Response, Overdose", "status": "closed"}, {"date": "5/7/2024 6:29:29 PM", "incident": "F240061232", "units": "E24", "address": "N 145th St / Linden Ave N", "types": "Aid Response", "status": "closed"}, {"date": "5/7/2024 6:24:36 PM", "incident": "F240061231", "units": "A4", "address": "2103 Western Ave", "types": "Aid Response", "status": "closed"}, {"date": "5/7/2024 6:22:04 PM", "incident": "F240061230", "units": "A31 M31", "address": "13202 Bitter Pl N", "types": "Medic Response", "status": "closed"}, {"date": "5/7/2024 6:12:51 PM", "incident": "F240061224", "units": "E24", "address": "13300 Stone Ave N", "types": "Alarm Bell", "status": "closed"}, {"date": "5/7/2024 6:14:58 P ...

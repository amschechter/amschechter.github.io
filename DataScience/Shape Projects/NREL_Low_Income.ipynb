# %% [markdown]
# ### Hello! This is my first attempt with geopandas we will #see #how #it #goes
#
# ##### Thanks to NREL for the data, find the set here ---> https://data.nrel.gov/submissions/222
#
# ###### more specifically this is the second one down "48e Program | Category 1 Shapefile" - Low-Income-Communities_Category1.zip

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt

zipfile = "C:/Users/aaron/Code/Data/Low-Income-Communities_Category1.zip"

geo_data_frame = geopandas.read_file(zipfile)

# %%
geo_data_frame.head()
# Out:
#     CensusTrac NMTC_Quali StateName CountyName NMTC_Vinta  CountyFIPS  \
# 0  01005950300        Yes   Alabama    Barbour       2015        1005
# 1  01005950900        Yes   Alabama    Barbour       2015        1005
# 2  01005950700        Yes   Alabama    Barbour       2015        1005
# 3  01005950600        Yes   Alabama    Barbour       2015        1005
# 4  01005950100        Yes   Alabama    Barbour       2015        1005
#
#                                             geometry
# 0  POLYGON ((-9520870.736 3745799.800, -9520881.5...
# 1  POLYGON ((-9480426.695 3741094.073, -9480434.5...
# 2  POLYGON ((-9478385.318 3749075.547, -9478384.5...
# 3  POLYGON ((-9478378.528 3748893.961, -9478377.7...
# 4  POLYGON ((-9497611.864 3782655.562, -9497527.2...

# %%
geo_data_frame.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 67077 entries, 0 to 67076
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CensusTrac  67077 non-null  object
#  1   NMTC_Quali  67077 non-null  object
#  2   StateName   67077 non-null  object
#  3   CountyName  67077 non-null  object
#  4   NMTC_Vinta  67077 non-null  object
#  5   CountyFIPS  67077 non-null  int64
#  6   geometry    67077 non-null  geometry
# dtypes: geometry(1), int64(1), object(5)
# memory usage: 3.6+ MB

# %%
geo_data_frame['StateName'].value_counts()
# Out:
# California                  7278
# Texas                       5663
# New York                    4263
# Florida                     3636
# Illinois                    2631
# Ohio                        2580
# Pennsylvania                2482
# Georgia                     2343
# Michigan                    2340
# North Carolina              2167
# Virginia                    1811
# Puerto Rico                 1692
# Tennessee                   1444
# New Jersey                  1433
# Arizona                     1408
# Missouri                    1366
# Alabama                     1327
# Louisiana                   1315
# Indiana                     1283
# Washington                  1236
# Kentucky                    1218
# Maryland                    1180
# Massachusetts               1139
# South Carolina              1130
# Minnesota                   1070
# Colorado                    1054
# Wisconsin                    991
# Oklahoma                     972
# ...

# %%
geo_data_frame.plot()
# Out:
# <Axes: >

# %%
exclude_list = ['Guam', 'American Samoa', 'Virgin Islands', 'Northern Mariana Islands', 'Alaska', 'Hawaii', 'Puerto Rico']
lower_48_mask = ~geo_data_frame['StateName'].isin(exclude_list)

lower_48_frame = geo_data_frame[lower_48_mask].plot()

# %%
include_list = ['Oregon', 'Washington', 'Idaho']
include_mask = geo_data_frame['StateName'].isin(include_list)
include_frame = geo_data_frame[include_mask].plot()

# %%
##Nice!! Now I am gonna try to do only the lower 48. I will use the 'StateName Category to help me out.'

geo_data_frame[geo_data_frame['StateName'] == 'District of Columbia'].plot()
# Out:
# <Axes: >

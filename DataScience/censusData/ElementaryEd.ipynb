# %% [markdown]
# Gonna test this elementary Ed data. We'll see how it goes. <br>
# Data from https://www.census.gov/data/tables/2021/econ/school-finances/secondary-education-finance.html <br>
# I chose the 'All data items' option

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_frame = pd.read_csv('C:/Users/aaron/Code/Data/Elementary-Secondary - elsec21.csv')


pd.set_option('display.max_columns', None) ### This line makes all the columns display, rather than ellipses shorten

data_frame.head()
# Out:
# C:\Users\aaron\AppData\Local\Temp\ipykernel_12752\1856645670.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = pd.read_csv('C:/Users/aaron/Code/Data/Elementary-Secondary - elsec21.csv')
#    STATE       IDCENSUS                              NAME  CONUM  CSA   CBSA  \
# 0      1  1500100100000    AUTAUGA COUNTY SCHOOL DISTRICT   1001  388  33860
# 1      1  1500200100000    BALDWIN COUNTY SCHOOL DISTRICT   1003  380  19300
# 2      1  1500200200000  GULF SHORES CITY SCHOOL DISTRICT   1003  380  19300
# 3      1  1500300100000    BARBOUR COUNTY SCHOOL DISTRICT   1005    N  21640
# 4      1  1500300200000      EUFAULA CITY SCHOOL DISTRICT   1005    N  21640
#
#    SCHLEV  NCESID  YRDATA    V33  TOTALREV  TFEDREV   C14   C15  C19  C22  \
# 0       3  100240      21   8955     98691    16308  2185  2288  169  279
# 1       3  100270      21  30210    450001    42447  6237  6692  386  709
# ...

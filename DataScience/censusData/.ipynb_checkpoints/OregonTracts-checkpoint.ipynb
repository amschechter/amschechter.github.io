# %% [markdown]
# ### HELLO!!! gLAD TO BE HERE I AM
# ### This data comes from here - https://catalog.data.gov/dataset/census-tracts
# ##### I am going to try to make a longitudinal pop map. Could be tough!!
# ###### Visit this link to see the tracts mapped out nicely -> https://geohub.oregon.gov/datasets/oregon-geo::2020-census-tracts/explore
# ###### View metadata, including some more detail on what the columns are here --> https://www.arcgis.com/sharing/rest/content/items/d589210147204f0286289d1636aa86ed/info/metadata/metadata.xml?format=default&output=html

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_frame = pd.read_csv('C:/Users/aaron/Code/Data/Oregon_Census_Tracts.csv')

pd.set_option('display.max_columns', None) ### This line makes all the columns display, rather than ellipses shorten

data_frame.head()
# Out:
#    OBJECTID_12  OBJECTID_1  STATEFP  COUNTYFP  TRACTCE        GEOID     NAME  \
# 0            1           1       41        19   100000  41019100000  1000.00
# 1            2           2       41        53    20306  41053020306   203.06
# 2            3           3       41        53     5204  41053005204    52.04
# 3            4           4       41        19   180000  41019180000  1800.00
# 4            5           5       41        19   200000  41019200000  2000.00
#
#               NAMELSAD  MTFCC FUNCSTAT       ALAND    AWATER   INTPTLAT  \
# 0    Census Tract 1000  G5020        S  2972506997  16731802  43.325113
# 1  Census Tract 203.06  G5020        S   220829030   1880612  44.795449
# 2   Census Tract 52.04  G5020        S     4002467    570220  44.934677
# 3    Census Tract 1800  G5020        S   349582103     20841  43.097561
# 4    Census Tract 2000  G5020        S   244952194    240125  42.929343
#
#      INTPTLON      GEOCODE          COUNTY               NAME_1    LABEL  \
# 0 -122.542848  41019100000  Douglas County    Census Tract 1000  1000.00
# 1 -123.245202  41053020306     Polk County  Census Tract 203.06   203.06
# 2 -123.093903  41053005204     Polk County   Census Tract 52.04    52.04
# 3 -123.153871  41019180000  Douglas County    Census Tract 1800  1800.00
# 4 -123.368369  41019200000  Douglas County    Census Tract 2000  2000.00
#
#    LOGRECNO  POP20  HHPOP20  GQPOP20  IGQPOP20  NGQPOP20  P20_LT18  P20_GE18  \
# 0       483   3103     3101        2         0         2       558      2545
# 1      1045   1988     1988        0         0         0       386      1602
# 2      1034   3813     3806        7         0         7       867      2946
# 3       495   4730     4730        0         0         0       937      3793
# 4       497   4902     4758      144         0       144       920      3982
#
#    POPDENS20  HU20  HU_OCC20  HU_VAC20  PPH20  NH_NAT20  NH_ASN20  NH_BLK20  \
# 0       2.70  1484      1292       192   2.40        48        14         6
# 1      23.32   781       738        43   2.69        14        15         0
# 2    2467.38  1660      1535       125   2.48        49       133        55
# 3      35.04  2062      1895       167   2.50       100        43         9
# 4      51.83  2221      2011       210   2.37       126        92        26
#
#    NH_PAC20  NH_OTH20  NH_WHT20  NH_MULT20  HISP20  H_NAT20  H_ASN20  H_BLK20  \
# 0         2        16      2570        302     145        6        3        0
# 1         0        10      1669         94     186        7        1        0
# 2        21        16      2808        211     520       17        0        5
# 3         8        13      3951        358     248       15        4        1
# %%
### Ok now I am going to make two new columns to shorten latitude and longtitude so i can categorize them

#data_frame['short_long'] = data_frame.round({'INTPTLON':2})
#data_frame['short_lat'] = data_frame.round({'INTPTLAT':2})

data_frame['short_lat'] = data_frame.INTPTLAT.round(1)
data_frame['short_long'] = data_frame.INTPTLON.round(1)


data_frame.head()
# Out:
#    OBJECTID_12  OBJECTID_1  STATEFP  COUNTYFP  TRACTCE        GEOID     NAME  \
# 0            1           1       41        19   100000  41019100000  1000.00
# 1            2           2       41        53    20306  41053020306   203.06
# 2            3           3       41        53     5204  41053005204    52.04
# 3            4           4       41        19   180000  41019180000  1800.00
# 4            5           5       41        19   200000  41019200000  2000.00
#
#               NAMELSAD  MTFCC FUNCSTAT       ALAND    AWATER   INTPTLAT  \
# 0    Census Tract 1000  G5020        S  2972506997  16731802  43.325113
# 1  Census Tract 203.06  G5020        S   220829030   1880612  44.795449
# 2   Census Tract 52.04  G5020        S     4002467    570220  44.934677
# 3    Census Tract 1800  G5020        S   349582103     20841  43.097561
# 4    Census Tract 2000  G5020        S   244952194    240125  42.929343
#
#      INTPTLON      GEOCODE          COUNTY               NAME_1    LABEL  \
# 0 -122.542848  41019100000  Douglas County    Census Tract 1000  1000.00
# 1 -123.245202  41053020306     Polk County  Census Tract 203.06   203.06
# 2 -123.093903  41053005204     Polk County   Census Tract 52.04    52.04
# 3 -123.153871  41019180000  Douglas County    Census Tract 1800  1800.00
# 4 -123.368369  41019200000  Douglas County    Census Tract 2000  2000.00
#
#    LOGRECNO  POP20  HHPOP20  GQPOP20  IGQPOP20  NGQPOP20  P20_LT18  P20_GE18  \
# 0       483   3103     3101        2         0         2       558      2545
# 1      1045   1988     1988        0         0         0       386      1602
# 2      1034   3813     3806        7         0         7       867      2946
# 3       495   4730     4730        0         0         0       937      3793
# 4       497   4902     4758      144         0       144       920      3982
#
#    POPDENS20  HU20  HU_OCC20  HU_VAC20  PPH20  NH_NAT20  NH_ASN20  NH_BLK20  \
# 0       2.70  1484      1292       192   2.40        48        14         6
# 1      23.32   781       738        43   2.69        14        15         0
# 2    2467.38  1660      1535       125   2.48        49       133        55
# 3      35.04  2062      1895       167   2.50       100        43         9
# 4      51.83  2221      2011       210   2.37       126        92        26
#
#    NH_PAC20  NH_OTH20  NH_WHT20  NH_MULT20  HISP20  H_NAT20  H_ASN20  H_BLK20  \
# 0         2        16      2570        302     145        6        3        0
# 1         0        10      1669         94     186        7        1        0
# 2        21        16      2808        211     520       17        0        5
# 3         8        13      3951        358     248       15        4        1
# 4         4        32      4101        246     275       11        0        0
#
#    H_PAC20  H_OTH20  H_WHT20  H_MULT20  NAT_AOIC20  ASN_AOIC20  BLK_AOIC20  \
# 0        0       22       50        64         171          37          26
# 1        0       97       23        58          71          37          17
# 2        0      151      136       211         171         214         114
# 3        0       29      110        89         370          84          44
# 4        0       76      126        62         321         115          55
#
#    PAC_AOIC20  OTH_AOIC20  WHT_AOIC20  NH18NAT20  NH18ASN20  NH18BLK20  \
# 0           9         267        2973         37         12          6
# 1           2         187        1839         14         14          0
# 2          46         394        3347         32        103         40
# 3          22         182        4502         71         40          7
# 4           7         196        4530         97         70         25
#
#    NH18PAC20  NH18OTH20  NH18WHT20  NH18MULT20  HISP18  H18NAT20  H18ASN20  \
# 0          2         16       2137         229     106         6         3
# 1          0         10       1366          74     124         3         1
# 2         21         12       2289         128     321        12         0
# 3          8         11       3252         244     160        11         2
# 4          3         28       3391         188     180        10         0
#
#    H18BLK20  H18PAC20  H18OTH20  H18WHT20  H18MULT20  IGQ_COR20  IGQ_JUV20  \
# 0         0         0        15        46         36          0          0
# 1         0         0        69        17         34          0          0
# 2         1         0       110        89        109          0          0
# 3         0         0        26        69         52          0          0
# 4         0         0        60        70         40          0          0
#
#    IGQ_NURS20  IGQ_OTH20  NGQ_COLL20  NGQ_MIL20  NGQOTH20  AREALAND20  \
# 0           0          0           0          0         2  2972506997
# 1           0          0           0          0         0   220829030
# 2           0          0           0          0         7     4002467
# 3           0          0           0          0         0   349582103
# 4           0          0           0          0       144   244952194
#
#    AREAWATR20  ObjectID  Shape_Leng   SHAPE_Length    SHAPE_Area  short_lat  \
# 0    16731802       234    4.681742  588512.005211  5.646607e+09       43.3
# 1     1880612       796    0.839772  106722.937243  4.421452e+08       44.8
# 2      570220       785    0.163728   19731.523635  9.125059e+06       44.9
# 3       20841       246    1.390924  175439.386873  6.559004e+08       43.1
# 4      240125       248    1.145531  147171.886175  4.574748e+08       42.9
#
#    short_long
# 0      -122.5
# 1      -123.2
# 2      -123.1
# 3      -123.2
# 4      -123.4

# %%
data_frame.plot(x = 'short_long', xlabel = 'Longitude', y = 'short_lat', ylabel = 'Latitude', kind = 'scatter', s = 2, title = 'Oregon by pop tract location')
# Out:
# <Axes: title={'center': 'Oregon by pop tract location'}, xlabel='Longitude', ylabel='Latitude'>

# %%
long_pop_frame = data_frame.groupby('short_long').agg({'POP20':'sum'}).reset_index()

long_pop_frame
# Out:
#     short_long  POP20
# 0       -124.5      0
# 1       -124.4   9116
# 2       -124.3  22903
# 3       -124.2  38759
# 4       -124.1  22458
# ..         ...    ...
# 67      -117.3   7899
# 68      -117.2   2051
# 69      -117.1   1740
# 70      -117.0  19717
# 71      -116.9   2076
#
# [72 rows x 2 columns]

# %%
#long_pop_frame.plot(title = 'Population Map by Longitude', kind = 'bar', figsize = (15,10), legend = 'Population')

# %%
longitude = long_pop_frame['short_long']
pop = long_pop_frame['POP20']

fig, ax = plt.subplots()
bar_container = ax.bar(longitude, pop, width = 0.03)
ax.set(ylabel = 'Population', xlabel = 'Longitude (Bin size = 0.1)')
ax.text(-122.5, 505000, s = 'Portland', ha = 'center')
ax.text(-123.4, 415000, s = 'Salem/Eugene', ha = 'center')
ax.text(-121.3, 110000, s = 'Bend', ha = 'center')
#ax.text(-120.4, 2111, s = 'hello')

#plt.bar(-124.4, 21111, align='edge', width=0.03)

plt.rcParams["figure.figsize"] = (10,5.5)

plt.show()

# %%
lat_pop_frame = data_frame.groupby('short_lat').agg({'POP20':'sum'}).reset_index()

# %%
#lat_pop_frame.plot(title = 'Population Map of Oregon by Latitude', kind = 'barh', figsize = (10, 7))
lat_pop_frame['POP20'].size
# Out:
# 42

# %%
latitude = lat_pop_frame['short_lat']
pop = lat_pop_frame['POP20']

fig, ax = plt.subplots()
bar_container = ax.barh(latitude, pop, 0.05)
ax.set(ylabel = 'Latitude (Bin size = 0.1)', xlabel = 'Population',)
ax.text(1000000, 45.55, s = 'Portland', ha = 'center')
ax.text(200000, 44.95, s = 'Salem', ha = 'center')
ax.text(200000, 44.15, s = 'Eugene', ha = 'center')
ax.text(100000, 42.45, s = 'Medford', ha = 'center')
#ax.text(-123, 490000, s = 'Salem/Eugene', ha = 'center')
#ax.text(-121.3, 110000, s = 'Bend', ha = 'center')
#ax.text(-120.4, 2111, s = 'hello')

#plt.bar(-124.4, 21111, align='edge', width=0.03)

#plt.rcParams["figure.figsize"] = (10,5.5)

plt.show()

# %%
data_frame.head()
# Out:
#    OBJECTID_12  OBJECTID_1  STATEFP  COUNTYFP  TRACTCE        GEOID     NAME  \
# 0            1           1       41        19   100000  41019100000  1000.00
# 1            2           2       41        53    20306  41053020306   203.06
# 2            3           3       41        53     5204  41053005204    52.04
# 3            4           4       41        19   180000  41019180000  1800.00
# 4            5           5       41        19   200000  41019200000  2000.00
#
#               NAMELSAD  MTFCC FUNCSTAT       ALAND    AWATER   INTPTLAT  \
# 0    Census Tract 1000  G5020        S  2972506997  16731802  43.325113
# 1  Census Tract 203.06  G5020        S   220829030   1880612  44.795449
# 2   Census Tract 52.04  G5020        S     4002467    570220  44.934677
# 3    Census Tract 1800  G5020        S   349582103     20841  43.097561
# 4    Census Tract 2000  G5020        S   244952194    240125  42.929343
#
#      INTPTLON      GEOCODE          COUNTY               NAME_1    LABEL  \
# 0 -122.542848  41019100000  Douglas County    Census Tract 1000  1000.00
# 1 -123.245202  41053020306     Polk County  Census Tract 203.06   203.06
# 2 -123.093903  41053005204     Polk County   Census Tract 52.04    52.04
# 3 -123.153871  41019180000  Douglas County    Census Tract 1800  1800.00
# 4 -123.368369  41019200000  Douglas County    Census Tract 2000  2000.00
#
#    LOGRECNO  POP20  HHPOP20  GQPOP20  IGQPOP20  NGQPOP20  P20_LT18  P20_GE18  \
# 0       483   3103     3101        2         0         2       558      2545
# 1      1045   1988     1988        0         0         0       386      1602
# 2      1034   3813     3806        7         0         7       867      2946
# 3       495   4730     4730        0         0         0       937      3793
# 4       497   4902     4758      144         0       144       920      3982
#
#    POPDENS20  HU20  HU_OCC20  HU_VAC20  PPH20  NH_NAT20  NH_ASN20  NH_BLK20  \
# 0       2.70  1484      1292       192   2.40        48        14         6
# 1      23.32   781       738        43   2.69        14        15         0
# 2    2467.38  1660      1535       125   2.48        49       133        55
# 3      35.04  2062      1895       167   2.50       100        43         9
# 4      51.83  2221      2011       210   2.37       126        92        26
#
#    NH_PAC20  NH_OTH20  NH_WHT20  NH_MULT20  HISP20  H_NAT20  H_ASN20  H_BLK20  \
# 0         2        16      2570        302     145        6        3        0
# 1         0        10      1669         94     186        7        1        0
# 2        21        16      2808        211     520       17        0        5
# 3         8        13      3951        358     248       15        4        1
# 4         4        32      4101        246     275       11        0        0
#
#    H_PAC20  H_OTH20  H_WHT20  H_MULT20  NAT_AOIC20  ASN_AOIC20  BLK_AOIC20  \
# 0        0       22       50        64         171          37          26
# 1        0       97       23        58          71          37          17
# 2        0      151      136       211         171         214         114
# 3        0       29      110        89         370          84          44
# 4        0       76      126        62         321         115          55
#
#    PAC_AOIC20  OTH_AOIC20  WHT_AOIC20  NH18NAT20  NH18ASN20  NH18BLK20  \
# 0           9         267        2973         37         12          6
# 1           2         187        1839         14         14          0
# 2          46         394        3347         32        103         40
# 3          22         182        4502         71         40          7
# 4           7         196        4530         97         70         25
#
#    NH18PAC20  NH18OTH20  NH18WHT20  NH18MULT20  HISP18  H18NAT20  H18ASN20  \
# 0          2         16       2137         229     106         6         3
# 1          0         10       1366          74     124         3         1
# 2         21         12       2289         128     321        12         0
# 3          8         11       3252         244     160        11         2
# 4          3         28       3391         188     180        10         0
#
#    H18BLK20  H18PAC20  H18OTH20  H18WHT20  H18MULT20  IGQ_COR20  IGQ_JUV20  \
# 0         0         0        15        46         36          0          0
# 1         0         0        69        17         34          0          0
# 2         1         0       110        89        109          0          0
# 3         0         0        26        69         52          0          0
# 4         0         0        60        70         40          0          0
#
#    IGQ_NURS20  IGQ_OTH20  NGQ_COLL20  NGQ_MIL20  NGQOTH20  AREALAND20  \
# 0           0          0           0          0         2  2972506997
# 1           0          0           0          0         0   220829030
# 2           0          0           0          0         7     4002467
# 3           0          0           0          0         0   349582103
# 4           0          0           0          0       144   244952194
#
#    AREAWATR20  ObjectID  Shape_Leng   SHAPE_Length    SHAPE_Area  short_lat  \
# 0    16731802       234    4.681742  588512.005211  5.646607e+09       43.3
# 1     1880612       796    0.839772  106722.937243  4.421452e+08       44.8
# 2      570220       785    0.163728   19731.523635  9.125059e+06       44.9
# 3       20841       246    1.390924  175439.386873  6.559004e+08       43.1
# 4      240125       248    1.145531  147171.886175  4.574748e+08       42.9
#
#    short_long
# 0      -122.5
# 1      -123.2
# 2      -123.1
# 3      -123.2
# 4      -123.4

# %%
x_axis = data_frame['INTPTLON']
y_axis = data_frame['INTPTLAT']
color = data_frame['HU_OCC20']

plt.scatter(x_axis, y_axis, c = color, s = 2, cmap = 'seismic', marker='h')
plt.title('Number of Occupied Housing units')
plt.rcParams["figure.figsize"] = (10,5.5)
#plt.legend(loc = "lower left")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar()
plt.show()

# %%
x_axis = data_frame['INTPTLON']
y_axis = data_frame['INTPTLAT']
color = data_frame['HU_VAC20']

plt.scatter(x_axis, y_axis, c = color, s = 2, cmap = 'seismic', marker='h')
plt.title('Number of Vacant Housing units')
plt.rcParams["figure.figsize"] = (10,5.5)
#plt.legend(loc = "lower left")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar()
plt.show()

# %%
#data_frame['Percent Vacant'] = data_frame['HU_VAC20'] / data_frame['HU_OCC20']
data_frame['Percent Vacant'] = data_frame['HU_VAC20'] / data_frame['HU20']

# %%
x_axis = data_frame['INTPTLON']
y_axis = data_frame['INTPTLAT']
color = data_frame['Percent Vacant']

plt.scatter(x_axis, y_axis, c = color, s = 2, cmap = 'seismic', marker='h')
plt.title('Percent of Vacant Housing units')
plt.rcParams["figure.figsize"] = (10,5.5)
#plt.legend(loc = "lower left")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar()
plt.show()

# %%
#portland_metro_mask = data_frame['INTPTLAT'] > 45.2 and data_frame['INTPTLAT'] < 45.7 and data_frame['INTPTLON'] > 122.2 and data_frame['INTPTLON'] < 123.5
portland_metro_mask = (data_frame['INTPTLAT'] > 45.2) & (data_frame['INTPTLAT'] < 45.7) & (data_frame['INTPTLON'] < -122.2) & (data_frame['INTPTLON'] > -123.5)
portland_metro_frame = data_frame[portland_metro_mask]

portland_metro_frame.head()
# Out:
#     OBJECTID_12  OBJECTID_1  STATEFP  COUNTYFP  TRACTCE        GEOID    NAME  \
# 13           14          14       41         5    22708  41005022708  227.08
# 14           15          15       41         5    22302  41005022302  223.02
# 15           16          16       41         5    22606  41005022606  226.06
# 16           17          17       41         5    22707  41005022707  227.07
# 17           18          18       41         5    22907  41005022907  229.07
#
#                NAMELSAD  MTFCC FUNCSTAT     ALAND  AWATER   INTPTLAT  \
# 13  Census Tract 227.08  G5020        S  30661916  748690  45.297595
# 14  Census Tract 223.02  G5020        S  18529688   25698  45.344982
# 15  Census Tract 226.06  G5020        S   5342813       0  45.321182
# 16  Census Tract 227.07  G5020        S  17196176    5289  45.322841
# 17  Census Tract 229.07  G5020        S   1534104       0  45.259325
#
#       INTPTLON      GEOCODE            COUNTY               NAME_1   LABEL  \
# 13 -122.836123  41005022708  Clackamas County  Census Tract 227.08  227.08
# 14 -122.553191  41005022302  Clackamas County  Census Tract 223.02  223.02
# 15 -122.614665  41005022606  Clackamas County  Census Tract 226.06  226.06
# 16 -122.800657  41005022707  Clackamas County  Census Tract 227.07  227.07
# 17 -122.682152  41005022907  Clackamas County  Census Tract 229.07  229.07
#
#     LOGRECNO  POP20  HHPOP20  GQPOP20  IGQPOP20  NGQPOP20  P20_LT18  P20_GE18  \
# 13       333   4281     4281        0         0         0      1025      3256
# 14       323   6072     6060       12         1        11      1265      4807
# 15       330   6010     5991       19         4        15      1537      4473
# 16       332   8186     8167       19         0        19      2095      6091
# 17       340   4144     4144        0         0         0      1165      2979
#
#     POPDENS20  HU20  HU_OCC20  HU_VAC20  PPH20  NH_NAT20  NH_ASN20  NH_BLK20  \
# 13     361.61  1604      1555        49   2.75        25       102        59
# 14     848.71  2297      2215        82   2.74        53       138        53
# 15    2913.41  2161      2104        57   2.85        35       164        35
# 16    1232.93  3293      3169       124   2.58        33       508        97
# 17    6996.21  1444      1405        39   2.95        26        38        30
#
#     NH_PAC20  NH_OTH20  NH_WHT20  NH_MULT20  HISP20  H_NAT20  H_ASN20  \
# 13        16        24      2987        238     830       28        5
# 14         9        34      4991        319     475       21       10
# 15        16        39      4974        348     399       12        0
# 16        14        37      6190        501     806       21        7
# 17         6        15      2334        223    1472       30        6
#
#     H_BLK20  H_PAC20  H_OTH20  H_WHT20  H_MULT20  NAT_AOIC20  ASN_AOIC20  \
# 13        0        0      412      155       230         160         193
# 14        1        0      143      117       183         223         237
# 15        0        3       77      116       191         202         262
# 16        7        0      253      200       318         202         767
# 17        1        0      701      177       557         156         102
#
#     BLK_AOIC20  PAC_AOIC20  OTH_AOIC20  WHT_AOIC20  NH18NAT20  NH18ASN20  \
# 13         103          37         709        3600         21         80
# 14         101          43         398        5598         43        123
# 15          96          51         349        5621         29        132
# 16         202          62         676        7179         27        386
# 17          63          28        1334        3272         12         32
#
#     NH18BLK20  NH18PAC20  NH18OTH20  NH18WHT20  NH18MULT20  HISP18  H18NAT20  \
# 13         47          9         14       2429         145     511        20
# 14         35          9         24       4064         217     292        16
# 15         23          6         26       3805         190     262        12
# 16         73         11         25       4777         266     526        12
# 17         17          6          7       1853         132     920        18
#
#     H18ASN20  H18BLK20  H18PAC20  H18OTH20  H18WHT20  H18MULT20  IGQ_COR20  \
# 13         5         0         0       262        87        137          0
# 14         2         0         0        92        77        105          0
# 15         0         0         0        64        66        120          0
# 16         7         7         0       173       125        202          0
# 17         5         1         0       450       100        346          0
#
#     IGQ_JUV20  IGQ_NURS20  IGQ_OTH20  NGQ_COLL20  NGQ_MIL20  NGQOTH20  \
# 13          0           0          0           0          0         0
# 14          0           1          0           0          0        11
# 15          0           0          4           0          0        15
# 16          0           0          0           0          0        19
# 17          0           0          0           0          0         0
#
#     AREALAND20  AREAWATR20  ObjectID  Shape_Leng  SHAPE_Length    SHAPE_Area  \
# 13    30661916      748690        84    0.332823  43399.007372  6.347398e+07
# 14    18529688       25698        74    0.257218  32368.621877  3.756832e+07
# 15     5342813           0        81    0.132740  17582.273461  1.080609e+07
# 16    17196176        5289        83    0.260894  33582.241089  3.479453e+07
# 17     1534104           0        91    0.059900   7784.242678  3.096070e+06
#
#     short_lat  short_long  Percent Vacant
# 13       45.3      -122.8        0.030549
# 14       45.3      -122.6        0.035699
# 15       45.3      -122.6        0.026377
# 16       45.3      -122.8        0.037656
# 17       45.3      -122.7        0.027008

# %%
print('POP20 =', portland_metro_frame['POP20'].sum())
print('POP20_LT18 =', portland_metro_frame['P20_LT18'].sum())
print('POP20_GT18 =', portland_metro_frame['P20_GE18'].sum())
# Out:
# POP20 = 1876940
# POP20_LT18 = 383720
# POP20_GT18 = 1493220

# %%
x_axis = portland_metro_frame['INTPTLON']
y_axis = portland_metro_frame['INTPTLAT']
color = portland_metro_frame['Percent Vacant']

plt.scatter(x_axis, y_axis, c = color, s = 2, cmap = 'seismic', marker='h')
plt.title('Percent of Vacant Housing units in the Portland metro area')
plt.rcParams["figure.figsize"] = (10,5.5)
#plt.legend(loc = "lower left")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar()
plt.show()

# %%
x_axis = portland_metro_frame['INTPTLON']
y_axis = portland_metro_frame['INTPTLAT']
color = portland_metro_frame['POPDENS20']

plt.scatter(x_axis, y_axis, c = color, s = 2, cmap = 'seismic', marker='h')
plt.title('Population Density Portland metro area')
plt.rcParams["figure.figsize"] = (10,5.5)
#plt.legend(loc = "lower left")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar()
plt.show()

# %%
data_frame['Percent Household'] = data_frame['HHPOP20'] / data_frame['POP20']

# %%
x_axis = data_frame['INTPTLON']
y_axis = data_frame['INTPTLAT']
color = data_frame['Percent Household']

plt.scatter(x_axis, y_axis, c = color, s = 2, cmap = 'seismic', marker='h')
plt.title('Percent of the Population living in a household')
plt.rcParams["figure.figsize"] = (10,5.5)
#plt.legend(loc = "lower left")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar()
plt.show()

# %%
portland_metro_frame['Percent Household'] = portland_metro_frame['HHPOP20'] / portland_metro_frame['POP20']
#portland_metro_frame.info()
# Out:
# C:\Users\aaron\AppData\Local\Temp\ipykernel_37184\451000409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portland_metro_frame['Percent Household'] = portland_metro_frame['HHPOP20'] / portland_metro_frame['POP20']

# %%
x_axis = portland_metro_frame['INTPTLON']
y_axis = portland_metro_frame['INTPTLAT']
color = portland_metro_frame['Percent Household']

plt.scatter(x_axis, y_axis, c = color, s = 2, cmap = 'seismic', marker='h')
plt.title('Percent of the Population living in a "Household"')
plt.rcParams["figure.figsize"] = (10,5.5)
#plt.legend(loc = "lower left")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar()
plt.show()

# %%
x_axis = data_frame['POP20']
y_axis = data_frame['HU20']
color = data_frame['Percent Vacant']

#plt.annotate(text, xy, xytext=None, xycoords='data', textcoords=None, arrowprops=None, annotation_clip=None, **kwargs)
#plt.annotate('fewnoi', xy=(2000, 1500))


plt.scatter(x_axis, y_axis, c = color, s = 3, cmap = 'seismic', marker='h')
plt.title('Tract Population X Total Housing Unit')
plt.rcParams["figure.figsize"] = (10,5.5)
#plt.legend(loc = "lower left")
plt.xlabel('2020 Population')
#plt.ylabel('POPDENS20 (Persons per sq mile)')
plt.ylabel('Housing Units 2020')
cbar = plt.colorbar()
cbar.set_label("Percent of total housing units that are vacant")
plt.show()

# %%
x_axis = data_frame['POP20']
y_axis = data_frame['PPH20']
color = data_frame['Percent Vacant']

plt.scatter(x_axis, y_axis, c = color, s = 2, cmap = 'seismic', marker='h')
plt.title('???')
plt.rcParams["figure.figsize"] = (10,5.5)
#plt.legend(loc = "lower left")
plt.xlabel('PPH20')
#plt.ylabel('POPDENS20 (Persons per sq mile)')
plt.ylabel('POP20_LT18')
plt.colorbar()
plt.show()

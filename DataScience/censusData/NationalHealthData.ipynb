# %% [markdown]
# A look at national health data. At somepoint I may redownload this as a shape file, or try to combine it with another data set.
#
# We'll see. Also apparently this data only covers the 500 largest cities in the states
#
# Data from here --> https://arc-gis-hub-home-arcgishub.hub.arcgis.com/datasets/CalEMA::cdc-local-data-for-better-health/about?layer=3

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_frame = pd.read_csv('C:/Users/aaron/Code/Data/CDC_-_Local_Data_for_Better_Health.csv')

pd.set_option('display.max_columns', None) ### This line makes all the columns display, rather than ellipses shorten

data_frame.head()
# Out:
#    OBJECTID    TractFIPS StateAbbr StateName CountyName  CountyFIPS  \
# 0         1  15007041200        HI    Hawaii      Kauai       15007
# 1         2  15007040604        HI    Hawaii      Kauai       15007
# 2         3  15007040700        HI    Hawaii      Kauai       15007
# 3         4  15007040800        HI    Hawaii      Kauai       15007
# 4         5  15007040900        HI    Hawaii      Kauai       15007
#
#    TotalPopulation  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# 0              170                6.4      ( 4.6,  8.8)                 15.9
# 1             3139                6.7      ( 5.7,  7.9)                 24.8
# 2             8403                5.4      ( 4.6,  6.4)                 22.0
# 3             3771                8.0      ( 6.8,  9.5)                 20.6
# 4             5561                6.7      ( 5.6,  8.0)                 22.3
#
#   ARTHRITIS_Crude95CI  BINGE_CrudePrev BINGE_Crude95CI  BPHIGH_CrudePrev  \
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72337 entries, 0 to 72336
# Data columns (total 83 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   OBJECTID                72337 non-null  int64
#  1   TractFIPS               72337 non-null  int64
#  2   StateAbbr               72337 non-null  object
#  3   StateName               72337 non-null  object
#  4   CountyName              72337 non-null  object
#  5   CountyFIPS              72337 non-null  int64
#  6   TotalPopulation         72337 non-null  int64
#  7   ACCESS2_CrudePrev       68172 non-null  float64
#  8   ACCESS2_Crude95CI       68172 non-null  object
#  9   ARTHRITIS_CrudePrev     68172 non-null  float64
#  10  ARTHRITIS_Crude95CI     68172 non-null  object
#  11  BINGE_CrudePrev         68172 non-null  float64
#  12  BINGE_Crude95CI         68172 non-null  object
#  13  BPHIGH_CrudePrev        68172 non-null  float64
# ...

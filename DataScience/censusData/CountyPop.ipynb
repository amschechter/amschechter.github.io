# %%
import pandas as pd

data_frame = pd.read_csv('C:/Users/aaron/Code/DataScience/Data/co-est2022-pop.csv')

data_frame.head(10)

### Data set has pops for all counties in America for 2020, 2021 and 2022. 
### The first few rows are all messed up and should be column titles, I will fix this in the next cell.
# Out:
#   table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0  Annual Estimates of the Resident Population fo...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                      United States
# 4                           .Autauga County, Alabama
# 5                           .Baldwin County, Alabama
# 6                           .Barbour County, Alabama
# 7                              .Bibb County, Alabama
# 8                            .Blount County, Alabama
# 9                           .Bullock County, Alabama
#
#                      Unnamed: 1                          Unnamed: 2  \
# 0                           NaN                                 NaN
# 1  April 1, 2020 Estimates Base  Population Estimate (as of July 1)
# 2                           NaN                                2020
# ...

# %%
#### cleaning the column names.

### The below line is kinda funky looking but works to rename all the columns properly
data_frame = data_frame.rename(columns = {'table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)':'County Name', 'Unnamed: 1':'April 2020 Pop Estimate', 'Unnamed: 2':'July 2020 Pop Estimate', 'Unnamed: 3':'July 2021 Pop Estimate', 'Unnamed: 4':'July 2022 Pop Estimate'})

data_frame.head(8)
# Out:
#                                          County Name  \
# 0  Annual Estimates of the Resident Population fo...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                      United States
# 4                           .Autauga County, Alabama
# 5                           .Baldwin County, Alabama
# 6                           .Barbour County, Alabama
# 7                              .Bibb County, Alabama
#
#         April 2020 Pop Estimate              July 2020 Pop Estimate  \
# 0                           NaN                                 NaN
# 1  April 1, 2020 Estimates Base  Population Estimate (as of July 1)
# 2                           NaN                                2020
# 3                   331,449,520                         331,511,512
# 4                        58,802                              58,902
# 5                       231,761                             233,219
# ...
